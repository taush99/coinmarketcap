# %%
import sqlite3
con = sqlite3.connect('coin.db')
cursorObj = con.cursor()
cursorObj.execute("CREATE TABLE IF NOT EXISTS coin(id INTEGER PRIMARY KEY, symbol TEXT, amount INTEGER, price REAL)")
con.commit()

# %%
import pandas as pd

# %%
cursorObj.execute("SELECT * FROM coin")
coins = cursorObj.fetchall()
print(coins)
# Out:
# [(1, 'BTC', 2, 3250.0), (2, 'BNB', 5, 10.0), (4, 'ETH', 1, 140.0), (5, 'XMR', 5, 45.0), (6, 'XRP', 5, 0.2), (7, '', '', '')]

# %%
import requests
import json

# %%
api_request = requests.get("https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest?start=1&limit=300&convert=USD&CMC_PRO_API_KEY=c6e4c7e0-6413-44dd-85b2-9c145a762d4c")
api = json.loads(api_request.content)

# %%
print(api["data"][0]["quote"])
# Out:
# {'USD': {'price': 31241.892224520365, 'volume_24h': 67564480207.633865, 'percent_change_1h': -1.14939104, 'percent_change_24h': -1.56937486, 'percent_change_7d': -10.12596139, 'percent_change_30d': 18.54554912, 'market_cap': 581490281382.9453, 'last_updated': '2021-01-28T07:54:02.000Z'}}

# %%
table = pd.DataFrame(api["data"][1]["quote"],columns=api["data"][1]["quote"])

# %%
table.append(api["data"][2]["quote"],ignore_index=True)
# Out:
#                                                  USD
# 0                           2021-01-28T07:54:02.000Z
# 1                                        1.47493e+11
# 2                                          -0.453885
# 3                                          -0.487348
# 4                                            82.1719
# 5                                           -1.78546
# 6                                             1288.9
# 7                                        4.04889e+10
# 8  {'price': 1.00098823453909, 'volume_24h': 1116...

# %%
table = pd.DataFrame(api["data"])

# %%
api["data"][0]["quote"]["USD"]["price"]
# Out:
# 31241.892224520365

# %%
con = sqlite3.connect('coin.db')
cursorObj = con.cursor()
cursorObj.execute("DROP TABLE IF EXISTS coin_data;")
cursorObj.execute("CREATE TABLE IF NOT EXISTS coin_data(id INTEGER PRIMARY KEY, symbol TEXT, price REAL, market_cap REAL, volume_24h REAL)")
con.commit()

for i in range(0, 300):
    symbol = api["data"][i]["symbol"]
    current_price = api["data"][i]["quote"]["USD"]["price"]
    market_cap = api["data"][i]["quote"]["USD"]["market_cap"]
    volume_24h = api["data"][i]["quote"]["USD"]["volume_24h"]
    cursorObj.execute("INSERT INTO coin_data(symbol, price, market_cap, volume_24h) VALUES(?, ?, ?, ?)", (symbol, current_price, market_cap, volume_24h))
    con.commit()
                                       
cursorObj.close()
con.close()

# %%
con = sqlite3.connect('coin.db')
cursorObj = con.cursor()
cursorObj.execute("SELECT * FROM coin_data")
coins = cursorObj.fetchall()
pd_frame = pd.DataFrame(coins)
pd_frame
# Out:
#        0      1             2             3             4
# 0      1    BTC  31241.892225  5.814903e+11  6.756448e+10
# 1      2    ETH   1288.895004  1.474932e+11  4.048891e+10
# 2      3   USDT      1.000988  2.542699e+10  1.116697e+11
# 3      4    DOT     16.463206  1.497170e+10  3.209655e+09
# 4      5    XRP      0.257028  1.167010e+10  2.979259e+09
# ..   ...    ...           ...           ...           ...
# 295  296    BTU      0.517787  4.660830e+07  4.918038e+04
# 296  297    SNL      0.068463  4.646351e+07  8.021214e+05
# 297  298    LON      5.755002  4.524856e+07  7.355223e+07
# 298  299  CENNZ      0.037148  4.457778e+07  1.331886e+06
# 299  300    PCX      5.557258  4.292065e+07  4.097500e+06
#
# [300 rows x 5 columns]

# %%
import pandas as pd
import requests
import json
df = pd.DataFrame()

symbol = []
current_price = []
market_cap = []
volume_24h = []

api_request = requests.get("https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest?start=1&limit=300&convert=USD&CMC_PRO_API_KEY=1e6c18b1-d19e-47e0-bf94-c2df617ba16d")
api = json.loads(api_request.content)
for i in range(0, 199):
    symbol.append(api['data'][i]['symbol'])
    current_price.append(api['data'][i]['quote']['USD']['price'])
    market_cap.append(api['data'][i]['quote']['USD']['market_cap'])
    volume_24h.append(api['data'][i]['quote']['USD']['volume_24h'])

#     cursorObj.execute("INSERT INTO coin_data(symbol, price, market_cap, volume_24h) VALUES(?, ?, ?, ?)", (symbol, current_price, market_cap, volume_24h))
#     con.commit()

# %%
df = pd.DataFrame()
# df["A"] = pd.DataFrame(symbol,index=range(0,len(symbol)))
df = pd.DataFrame({'Symbol': symbol, 'Price': current_price, 'Market Cap': market_cap, 'Volume in 24h': volume_24h})
df
# Out:
#     Symbol         Price    Market Cap  Volume in 24h
# 0      BTC  36061.987558  6.714061e+11   6.340306e+10
# 1      ETH   1536.694228  1.759796e+11   4.380135e+10
# 2     USDT      1.001477  2.706183e+10   1.061239e+11
# 3      DOT     18.919397  1.715021e+10   3.104156e+09
# 4      XRP      0.375079  1.703010e+10   8.927566e+09
# ..     ...           ...           ...            ...
# 194    ETN      0.005409  5.534098e+07   8.772513e+05
# 195     IQ      0.005646  5.624231e+07   1.239011e+06
# 196    XHV      3.807606  5.505187e+07   9.870778e+05
# 197    QKC      0.008556  5.475600e+07   3.334456e+07
# 198   TRAC      0.160028  5.440840e+07   7.214263e+05
#
# [199 rows x 4 columns]

# %%
df.sort_values(by=['Price'], ascending=False)
# Out:
#      Symbol         Price    Market Cap  Volume in 24h
# 62   RENBTC  36148.558716  5.840671e+08   2.567352e+07
# 13     WBTC  36143.814983  4.253049e+09   1.744828e+08
# 0       BTC  36061.987558  6.714061e+11   6.340306e+10
# 96     BTCB  36046.473901  2.479554e+08   5.317430e+06
# 44      YFI  33832.210563  1.013910e+09   5.197566e+08
# ..      ...           ...           ...            ...
# 176      DX      0.001307  6.533881e+07   5.166550e+05
# 123     HOT      0.000785  1.316050e+08   2.716837e+07
# 142    NPXS      0.000444  1.045070e+08   2.189025e+07
# 77      BTT      0.000431  4.264798e+08   2.151639e+08
# 160     KIN      0.000055  8.349365e+07   8.722495e+05
#
# [199 rows x 4 columns]

# %%
df.sort_values(by=['Market Cap'], ascending=False)
# Out:
#     Symbol         Price    Market Cap  Volume in 24h
# 0      BTC  36061.987558  6.714061e+11   6.340306e+10
# 1      ETH   1536.694228  1.759796e+11   4.380135e+10
# 2     USDT      1.001477  2.706183e+10   1.061239e+11
# 3      DOT     18.919397  1.715021e+10   3.104156e+09
# 4      XRP      0.375079  1.703010e+10   8.927566e+09
# ..     ...           ...           ...            ...
# 195     IQ      0.005646  5.624231e+07   1.239011e+06
# 194    ETN      0.005409  5.534098e+07   8.772513e+05
# 196    XHV      3.807606  5.505187e+07   9.870778e+05
# 197    QKC      0.008556  5.475600e+07   3.334456e+07
# 198   TRAC      0.160028  5.440840e+07   7.214263e+05
#
# [199 rows x 4 columns]

# %%
from tkinter import *
from tkinter import messagebox, Menu
import requests
import json
import sqlite3
import pandas as pd

# %%
crypto = Tk()
crypto.title("My Crypto Portfolio")
crypto.iconbitmap('favicon.ico')
df = pd.DataFrame()

# %%
def insert_coin():

    symbol = []
    current_price = []
    market_cap = []
    volume_24h = []
    global df
    
    api_request = requests.get("https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest?start=1&limit=300&convert=USD&CMC_PRO_API_KEY=1e6c18b1-d19e-47e0-bf94-c2df617ba16d")
    api = json.loads(api_request.content)
    for i in range(0, 199):
        symbol.append(api['data'][i]['symbol'])
        current_price.append(api['data'][i]['quote']['USD']['price'])
        market_cap.append(api['data'][i]['quote']['USD']['market_cap'])
        volume_24h.append(api['data'][i]['quote']['USD']['volume_24h'])
#     print(symbol)
#     print(current_price)

    # df["A"] = pd.DataFrame(symbol,index=range(0,len(symbol)))
    df = pd.DataFrame({'Symbol': symbol, 'Price': current_price, 'Market Cap': market_cap, 'Volume in 24h': volume_24h})
    
    
def query_coin():
    coin_row = 1
    #print(df)
    global coins_price
    
    coins_price = df.sort_values(by=['Price'], ascending=False).to_records()
    coins_market_cap = df.sort_values(by=['Market Cap'], ascending=False).to_numpy()
    coins_volume_24h = df.sort_values(by=['Volume in 24h'], ascending=False).to_numpy()
#     print(coins_price)
#     print(coins_price.iloc[2][0])
    print(coins_price[1][0])

query_coin()
# Out:
# WBTC

# %%
#insert_coin()
query_coin()
# Out:
# [['BTC' 36561.326160182165 680702865318.8015 63614090287.746544]
#  ['WBTC' 36491.74269915612 4293989505.9585586 175169435.8787907]
#  ['RENBTC' 36461.589483164076 589124851.424479 25864190.66046171]
#  ['BTCB' 36196.46284392767 248987182.55185562 5336248.86353646]
#  ['YFI' 33679.02871785205 1009319787.3719479 526538211.4852584]
#  ['YFII' 1878.8587065379688 72516430.63753945 114956912.26657909]
#  ['PAXG' 1850.5615051345253 115156817.21453294 3888780.77780463]
#  ['MKR' 1690.4437099428699 1683160544.7499661 287862671.81385106]
#  ['ETH' 1554.1212700514898 177975355172.62238 43986788564.80787]
#  ['SFI' 1221.5922989586509 89868012.92069386 6510360.30322971]
#  ['BCH' 435.3464527484882 8116898565.729079 4801706506.756012]
#  ['KP3R' 402.8946128828431 80579325.4711815 9935706.88815641]
#  ['COMP' 353.0148570056529 1619180104.5740197 273949102.6666007]
#  ['AAVE' 318.800408740525 3929465892.633064 824313567.3002758]
#  ['BSV' 182.39544066146973 3400350621.3503127 680880333.583741]
#  ['XMR' 154.7607145949356 2759397216.30863 1610350673.1421962]
#  ['LTC' 151.4158079470768 10055704196.68246 8536807192.103068]
#  ['GNO' 126.35004746778924 190104891.56951353 1717874.70849157]
#  ['DASH' 116.1551523321327 1156471756.4594445 1057183848.479156]
#  ['KSM' 110.00071994684755 931716884.3192213 111180710.69746953]
#  ['ZEC' 95.53014039974315 1055723881.7123965 1123381826.046043]
#  ['DCR' 68.98385992657676 866451977.8358653 15341268.31166992]
#  ['EGLD' 65.65928407445627 1108396921.1187537 71343703.40311368]
#  ['BNB' 50.9018810017647 7866009432.941289 760163782.1435226]
#  ['LOOM' 0.06345590202796 61585269.8644274 20753485.02758885]
#  ['SNT' 0.05350118529567 185674996.20740673 31915296.97434796]
#  ['FUN' 0.04390381470463 287520778.4220864 30243158.5866252]
#  ['WAXP' 0.04317842117118 64968880.38149892 10988081.60691661]
#  ['VLX' 0.04251372242888 89546498.88702774 1500055.98190866]
#  ['BTS' 0.0410785566443 123024936.93731473 34047693.32173537]
#  ['MATIC' 0.04084906353191 199254819.18503174 28488238.63654319]
#  ['RSR' 0.03985740683442 372666714.04441786 235292072.9442426]
#  ['JST' 0.03636254633816 82191234.58630556 126471418.3605477]
#  ['TRX' 0.03389143110259 2428648340.573276 1295075196.815584]
#  ['DGB' 0.03212510862188 449795612.3607605 26281777.74727031]
#  ['TFUEL' 0.03178800758334 166440227.5779436 4835089.22284689]
#  ['DOGE' 0.03131076869684 4014668396.6962404 2204323947.0370636]
#  ['VET' 0.0287759512816 1850741910.0834582 332240006.79318273]
#  ['RVN' 0.02440043634763 196476461.54529583 33163573.78748547]
#  ['CHZ' 0.02326179572995 126569783.48836574 52094361.30135957]
#  ['IOST' 0.0167617737591 274460229.6143828 103707160.14373963]
#  ['XVG' 0.01619134511603 265977013.19002894 19998274.37089083]
#  ['STMX' 0.01507312561864 118820743.91710134 1532634079.8663297]
#  ['ANKR' 0.01400592484554 90985747.13115531 29871575.72781826]
#  ['IOTX' 0.0121393550515 117075635.85008118 18258756.42922864]
#  ['REV' 0.01166372101834 992133438.4917442 5196522.43234026]
#  ['ONE' 0.01002056463253 94888722.05025499 12136925.29437649]
#  ['MFT' 0.00926962629122 92696262.9122 41152770.57150867]
#  ['SC' 0.00893865917174 405714682.6123739 131074407.76333691]
#  ['QKC' 0.00886468607516 56733162.00628191 37273440.20035574]
#  ['CKB' 0.00658725764956 156753615.34124303 15156019.02596722]
#  ['IQ' 0.00653188481098 65072446.23445755 75288451.68338871]
#  ['ETN' 0.00542071837276 55464946.72858525 886577.08159148]
#  ['RDD' 0.00304233463578 87645745.9008688 4069806.0505752]
#  ['DX' 0.00131541636519 65770818.25908722 495650.67054771]
#  ['HOT' 0.00079171667209 132764397.7190443 27481890.73931277]
#  ['NPXS' 0.00044579295225 104990886.18745007 22435948.30369756]
#  ['BTT' 0.00043488944588 430529178.872939 217143550.69918942]
#  ['KIN' 5.577596618e-05 84674283.26289076 871174.42878387]]
# WBTC

# %%
df
# Out:
#     Symbol         Price    Market Cap  Volume in 24h
# 0      BTC  36561.326160  6.807029e+11   6.361409e+10
# 1      ETH   1554.121270  1.779754e+11   4.398679e+10
# 2     USDT      1.001567  2.706426e+10   1.065073e+11
# 3      DOT     18.863711  1.709973e+10   3.238556e+09
# 4      XRP      0.375627  1.705497e+10   8.919795e+09
# ..     ...           ...           ...            ...
# 194    QKC      0.008865  5.673316e+07   3.727344e+07
# 195    DIA      2.015843  5.699174e+07   3.376210e+07
# 196    ETN      0.005421  5.546495e+07   8.865771e+05
# 197   TRAC      0.160446  5.455029e+07   7.286539e+05
# 198    XHV      3.779751  5.464913e+07   8.295590e+05
#
# [199 rows x 4 columns]

# %%
arr = df.to_numpy()
arr[0][1]
# Out:
# 36561.326160182165
